# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/train.csv")
test = pd.read_csv("/content/test.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
list = ["passenger's id", 'Survival(0/1)', 'Ticket class', 'Name of the passenger', 'Gender of the passenger', 'Age of the passenger', 'No. of siblings/ spouses aboard', 'No. of parents/ children', 'Ticket number', 'Passenger fare','Cabin nmber', 'embarkment port']
columns = data.columns

# %%
pd.DataFrame({'Attribute': data.columns, 'Description': list})
# Out:
#       Attribute                      Description
# 0   PassengerId                   passenger's id
# 1      Survived                    Survival(0/1)
# 2        Pclass                     Ticket class
# 3          Name            Name of the passenger
# 4           Sex          Gender of the passenger
# 5           Age             Age of the passenger
# 6         SibSp  No. of siblings/ spouses aboard
# 7         Parch         No. of parents/ children
# 8        Ticket                    Ticket number
# 9          Fare                   Passenger fare
# 10        Cabin                      Cabin nmber
# 11     Embarked                  embarkment port

# %%
dict
# Out:
# dict

# %%
data.loc[:, 'Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
column_names = data.columns
column_names = column_names.drop(['Name', 'Ticket', 'Cabin'])
data.Sex.replace({'female': 0, 'male': 1}, inplace = True)
data.Sex.value_counts()
# Out:
# 1    577
# 0    314
# Name: Sex, dtype: int64

# %%
sns.set_theme()
data.isnull().sum().plot(kind = 'bar')
plt.title("Null values in the dataset")
plt.xlabel("Columns/ Attributes")
plt.ylabel("Number of values")
plt.show()

# %%
l = [0, 1, 2, 4, 5, 6, 7, 9]
len(l)
# Out:
# 8

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
column = data.columns
column
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
j = 1
plt.figure(figsize = (13, 20))
sns.set_theme()
for i in l:
    plt.subplot(4, 2, j)
    sns.violinplot(data = data.iloc[:, i], x = data.iloc[:, i])
#     sns.rugplot(data = data.iloc[:, i], x = data.iloc[:, i])
    plt.title(f"Violin plot for the {column[i]} column in titanic dataset")
    j = j+1

plt.show()

# %%
sns.set_theme()
sns.violinplot(data.iloc[:, 5], x = data.iloc[:, 5])
plt.title("Violin plot for the Age column in the titanic dataset")
plt.show()

# %%
 data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
j = 1
plt.figure(figsize = (15,15))
for i in l:
    plt.subplot(4, 2, j)
    sns.countplot(data = data.iloc[:, i], x = data.iloc[:, i])
    plt.title(f"Count plot of {column[i]} column")
    j = j+1
plt.tight_layout()
plt.show()
# j = 1
# plt.figure(figsize = (12, 20))
# sns.set_theme()
# for i in l:
#     plt.subplot(4, 2, j)
#     sns.violinplot(data = data.iloc[:, i], x = data.iloc[:, i])
# #     sns.rugplot(data = data.iloc[:, i], x = data.iloc[:, i])
#     plt.title(f"Violin plot for the {column[i]} column in titanic dataset")
#     j = j+1

# plt.show()

# %%
sns.countplot(data.Cabin, x = data.Cabin)
plt.show()

# %%
data.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
data.drop(['Cabin', ], axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
for i in range(1, len(column_names), 1):
    print(data.iloc[:, i].value_counts().sum())
# Out:
# 891
# 891
# 891
# 891
# 714
# 891
# 891
# 891

# %%
g = sns.barplot(data = data, x = data.iloc[:, 1], hue = data.iloc[:, 4] )
# plt.bar_label(g)
# plt.ylabel("Percentage")

# %%
# c1 = 1
# rows = 16
# col = 8
# plt.figure(figsize = (30, 30))
# for i in l:
#     for j in l:
#         plt.subplot(rows, col, c1)
#         sns.barplot(data = data, x = data.iloc[:, i], y = data.iloc[:, j], hue = data.iloc[:,j])
#         plt.title(f"{column[i]} V {column[j]}")
#         c1 = c1+1
# plt.show()

# %%
g = sns.PairGrid(data)
g.map_diag(sns.histplot)
g.map_offdiag(sns.kdeplot)

# %%
sns.pairplot(data)

# %%
g = sns.PairGrid(data)
g.map_diag(sns.histplot)
g.map_offdiag(sns.violinplot)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score, precision_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.compose import make_column_transformer

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
data.drop(['Cabin', 'PassengerId'], axis = 1, inplace = True)

# %%
data.drop('Name', axis = 1, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
data.fillna(method = 'ffill', inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Embarked  891 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
X = data.iloc[:, 1:9]
y = data.Survived

# %%
X.info(), y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    int64
#  1   Sex       891 non-null    int64
#  2   Age       891 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Ticket    891 non-null    object
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Survived
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    int64
# dtypes: int64(1)
# memory usage: 7.1 KB
# (None, None)

# %%
X_train, val_train, y_train, val_test = train_test_split(X, y, test_size = 0.1, random_state = 42)

# %%
X_train.info(), val_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 801 entries, 165 to 102
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    801 non-null    int64
#  1   Sex       801 non-null    int64
#  2   Age       801 non-null    float64
#  3   SibSp     801 non-null    int64
#  4   Parch     801 non-null    int64
#  5   Ticket    801 non-null    object
#  6   Fare      801 non-null    float64
#  7   Embarked  801 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 56.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 709 to 250
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    90 non-null     int64
#  1   Sex       90 non-null     int64
#  2   Age       90 non-null     float64
#  3   SibSp     90 non-null     int64
#  4   Parch     90 non-null     int64
# ...

# %%
o = 0
s = 0
for i in range(0, 8):
  if X_train.iloc[:, i].dtype == 'object':
    o += 1
  elif X_train.iloc[:, i].dtype == 'int64' or X_train.iloc[:, i].dtype == 'float64':
    s += 1

  else:
    print("you dumb o what")
print(f"endeded values: {o}")
print(f"scaled values: {s}")
# Out:
# endeded values: 2
# scaled values: 6

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 801 entries, 165 to 102
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    801 non-null    int64
#  1   Sex       801 non-null    int64
#  2   Age       801 non-null    float64
#  3   SibSp     801 non-null    int64
#  4   Parch     801 non-null    int64
#  5   Ticket    801 non-null    object
#  6   Fare      801 non-null    float64
#  7   Embarked  801 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 56.3+ KB

# %%
ct = make_column_transformer(
    (MinMaxScaler(), [0, 1, 2, 3, 4, 6]),
    (OneHotEncoder(), [5, 7]),
    remainder='passthrough'
)

# %%
ct.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('minmaxscaler', MinMaxScaler(),
#                                  [0, 1, 2, 3, 4, 6]),
#                                 ('onehotencoder', OneHotEncoder(), [5, 7])])

# %%
print(X_train.columns, val_train.columns)
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'], dtype='object') Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'], dtype='object')

# %%
X_train_norm = ct.transform(X_train)

# %%
ct.fit(val_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('minmaxscaler', MinMaxScaler(),
#                                  [0, 1, 2, 3, 4, 6]),
#                                 ('onehotencoder', OneHotEncoder(), [5, 7])])

# %%
val_train_norm = ct.transform(val_train)

# %%
neigh = np.arange(1, 20)
accuracy = []
for i in range(1, len(neigh)):
  model = KNeighborsClassifier(n_neighbors = i)
  model.fit(X_train, y_train)
  accuracy[i-1] = model.score(X_test, y_test)
plt.plot(accuracy, kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-79eea7e707a6> in <cell line: 3>()
#       3 for i in range(1, len(neigh)):
#       4   model = KNeighborsClassifier(n_neighbors = i)
# ----> 5   model.fit(X_train, y_train)
#       6   accuracy[i-1] = model.score(X_test, y_test)
#       7 plt.plot(accuracy, kind = 'bar')
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     213         self._validate_params()
#     214
# --> 215         return self._fit(X, y)
#     216
#     217     def predict(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     452         if self._get_tags()["requires_y"]:
#     453             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 454                 X, y = self._validate_data(
# ...

# %%
sns.countplot(data = data, x = data.loc[:, 'Survived'])

# %%
print(data.Pclass.unique())

# %%
g = sns.PairGrid(data = data)
g.map_diag(sns.histplot())
g.map_offdiag(sns.countplot())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-5e8f72eaa05c> in <cell line: 2>()
#       1 g = sns.PairGrid(data = data)
# ----> 2 g.map_diag(sns.histplot())
#       3 g.map_offdiag(sns.countplot())
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1476             self.diag_axes = np.array(diag_axes, np.object_)
#    1477
# -> 1478         if "hue" not in signature(func).parameters:
#    1479             return self._map_diag_iter_hue(func, **kwargs)
#    1480
#
# /usr/lib/python3.10/inspect.py in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3252 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3253     """Get a signature object for the passed callable."""
# -> 3254     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
# ...
